# %%
# tester.ipynb
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))


# from src.analyzer import analyze_speech
from src.analyzer_raw import analyze_speech

# Quick analysis
result = analyze_speech("../data/l2arctic_spontaneous/L2A_001.wav")
# result = analyze_speech("../samples/sample4.flac")

# Access results
# print(f"Score: {result['verdict']['fluency_score']}")
# print(f"Fillers detected: {len(result['filler_events'])}")

result
# Out:
# Analyzing audio: ../data/l2arctic_spontaneous/L2A_001.wav
# Context: conversational
#
# [1/5] Transcribing with Whisper (verbatim)...
#   Duration: 66.04s
#   Words: 136
#
# [2/5] Marking filler words...
#   Marked: 0 filler words
#   Content words: 136
#
# [3/5] Aligning words with WhisperX...
#   Aligned: 136 words
#
# [4/5] Detecting subtle fillers with Wav2Vec2...
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   Total events: 14
#
# [5/5] Calculating raw score...
# {'raw_transcript': "Long, long ago in a really big city and in a corner of the building, a man and a woman just want to go to their destination and they both carry the same cases. And but suddenly in a corner, the man and the woman bumped into with each other and they just fold down. And since their cases are the same. They didn't pay attention to that so they just grab one and go to their destination. Oh, go to their home and maybe their office. But when the man around his office, he opened the case and found out that this case belongs to the woman. And when the woman went back to his home, she found to her home and she found out that the case belongs to them. So that's a mistake.",
#  'wpm': 123.56147789218655,
#  'unique_word_count': 72,
#  'fillers_per_min': np.float64(2.5439127801332533),
#  'stutters_per_min': 0.0,
#  'long_pauses_per_min': 0.0,
#  'very_long_pauses_per_min': 0.0,
#  'pause_frequency': 7.26832222895215,
#  'pause_time_ratio': np.float64(0.07389460932768031),
#  'pause_variability': np.float64(0.17435595774162807),
#  'vocab_richness': 0.5294117647058824,
#  'repetition_ratio': np.float64(0.043478260869565216),
#  'speech_rate_variability': np.float64(0.2412644733530836),
#  'mean_utterance_length': np.float64(17.0),
#  'pause_after_filler_rate': 0.0,
#  'mean_word_confidence': np.float64(0.8761064569082331),
#  'low_confidence_ratio': np.float64(0.18382352941176472),
#  'lexical_density': 0.5073529411764706,
#  'statistics': {'total_words_transcribed': 136,
#   'content_words': 136,
#   'filler_words_detected': np.int64(0),
#   'filler_percentage': np.float64(0.0)},
#  'timestamps': {'words_timestamps_raw': [{'word': 'Long,',
#     'start': 0.0,
#     'end': 0.28,
#     'duration': 0.28,
#     'confidence': 0.07641933858394623,
#     'is_filler': False},
#    {'word': 'long',
#     'start': 0.48,
#     'end': 0.64,
#     'duration': 0.16000000000000003,
#     'confidence': 0.9759964942932129,
#     'is_filler': False},
#    {'word': 'ago',
#     'start': 0.64,
#     'end': 1.16,
#     'duration': 0.5199999999999999,
#     'confidence': 0.955901563167572,
#     'is_filler': False},
#    {'word': 'in',
#     'start': 1.16,
#     'end': 1.76,
#     'duration': 0.6000000000000001,
#     'confidence': 0.6517712473869324,
#     'is_filler': False},
#    {'word': 'a',
#     'start': 1.76,
#     'end': 1.9,
#     'duration': 0.1399999999999999,
#     'confidence': 0.9493395090103149,
#     'is_filler': False},
#    {'word': 'really',
#     'start': 1.9,
#     'end': 2.2,
#     'duration': 0.30000000000000027,
#     'confidence': 0.83961421251297,
#     'is_filler': False},
#    {'word': 'big',
#     'start': 2.2,
#     'end': 2.52,
#     'duration': 0.31999999999999984,
#     'confidence': 0.992954432964325,
#     'is_filler': False},
#    {'word': 'city',
#     'start': 2.52,
#     'end': 3.04,
#     'duration': 0.52,
#     'confidence': 0.9963235855102539,
#     'is_filler': False},
#    {'word': 'and',
#     'start': 3.04,
#     'end': 4.02,
#     'duration': 0.9799999999999995,
#     'confidence': 0.6349655389785767,
#     'is_filler': False},
#    {'word': 'in',
#     'start': 4.02,
#     'end': 4.26,
#     'duration': 0.2400000000000002,
#     'confidence': 0.9241474270820618,
#     'is_filler': False},
#    {'word': 'a',
#     'start': 4.26,
#     'end': 4.42,
#     'duration': 0.16000000000000014,
#     'confidence': 0.5630697011947632,
#     'is_filler': False},
#    {'word': 'corner',
#     'start': 4.42,
#     'end': 5.0,
#     'duration': 0.5800000000000001,
#     'confidence': 0.9991878867149353,
#     'is_filler': False},
#    {'word': 'of',
#     'start': 5.0,
#     'end': 5.46,
#     'duration': 0.45999999999999996,
#     'confidence': 0.9919318556785583,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 5.46,
#     'end': 5.72,
#     'duration': 0.2599999999999998,
#     'confidence': 0.9847453236579895,
#     'is_filler': False},
#    {'word': 'building,',
#     'start': 5.72,
#     'end': 6.22,
#     'duration': 0.5,
#     'confidence': 0.9915297031402588,
#     'is_filler': False},
#    {'word': 'a',
#     'start': 6.6,
#     'end': 7.12,
#     'duration': 0.5200000000000005,
#     'confidence': 0.8921689391136169,
#     'is_filler': False},
#    {'word': 'man',
#     'start': 7.12,
#     'end': 7.44,
#     'duration': 0.3200000000000003,
#     'confidence': 0.9884127974510193,
#     'is_filler': False},
#    {'word': 'and',
#     'start': 7.44,
#     'end': 8.0,
#     'duration': 0.5599999999999996,
#     'confidence': 0.9644271731376648,
#     'is_filler': False},
#    {'word': 'a',
#     'start': 8.0,
#     'end': 8.24,
#     'duration': 0.2400000000000002,
#     'confidence': 0.6371814608573914,
#     'is_filler': False},
#    {'word': 'woman',
#     'start': 8.24,
#     'end': 8.5,
#     'duration': 0.2599999999999998,
#     'confidence': 0.8666236996650696,
#     'is_filler': False},
#    {'word': 'just',
#     'start': 8.5,
#     'end': 9.46,
#     'duration': 0.9600000000000009,
#     'confidence': 0.9478781819343567,
#     'is_filler': False},
#    {'word': 'want',
#     'start': 9.46,
#     'end': 9.96,
#     'duration': 0.5,
#     'confidence': 0.48793306946754456,
#     'is_filler': False},
#    {'word': 'to',
#     'start': 9.96,
#     'end': 10.2,
#     'duration': 0.23999999999999844,
#     'confidence': 0.982209324836731,
#     'is_filler': False},
#    {'word': 'go',
#     'start': 10.2,
#     'end': 10.8,
#     'duration': 0.6000000000000014,
#     'confidence': 0.9909919500350952,
#     'is_filler': False},
#    {'word': 'to',
#     'start': 10.8,
#     'end': 11.22,
#     'duration': 0.41999999999999993,
#     'confidence': 0.9805959463119507,
#     'is_filler': False},
#    {'word': 'their',
#     'start': 11.22,
#     'end': 11.58,
#     'duration': 0.35999999999999943,
#     'confidence': 0.9881580471992493,
#     'is_filler': False},
#    {'word': 'destination',
#     'start': 11.58,
#     'end': 12.82,
#     'duration': 1.2400000000000002,
#     'confidence': 0.9958012700080872,
#     'is_filler': False},
#    {'word': 'and',
#     'start': 12.82,
#     'end': 13.58,
#     'duration': 0.7599999999999998,
#     'confidence': 0.6094791889190674,
#     'is_filler': False},
#    {'word': 'they',
#     'start': 13.58,
#     'end': 13.84,
#     'duration': 0.2599999999999998,
#     'confidence': 0.9882104396820068,
#     'is_filler': False},
#    {'word': 'both',
#     'start': 13.84,
#     'end': 14.26,
#     'duration': 0.41999999999999993,
#     'confidence': 0.9969285130500793,
#     'is_filler': False},
#    {'word': 'carry',
#     'start': 14.26,
#     'end': 14.66,
#     'duration': 0.40000000000000036,
#     'confidence': 0.6884579062461853,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 14.66,
#     'end': 14.9,
#     'duration': 0.2400000000000002,
#     'confidence': 0.9774173498153687,
#     'is_filler': False},
#    {'word': 'same',
#     'start': 14.9,
#     'end': 15.26,
#     'duration': 0.35999999999999943,
#     'confidence': 0.9938567280769348,
#     'is_filler': False},
#    {'word': 'cases.',
#     'start': 15.26,
#     'end': 15.78,
#     'duration': 0.5199999999999996,
#     'confidence': 0.9557271003723145,
#     'is_filler': False},
#    {'word': 'And',
#     'start': 16.5,
#     'end': 17.04,
#     'duration': 0.5399999999999991,
#     'confidence': 0.630698025226593,
#     'is_filler': False},
#    {'word': 'but',
#     'start': 17.04,
#     'end': 17.2,
#     'duration': 0.16000000000000014,
#     'confidence': 0.7018191814422607,
#     'is_filler': False},
#    {'word': 'suddenly',
#     'start': 17.2,
#     'end': 17.62,
#     'duration': 0.4200000000000017,
#     'confidence': 0.6018807291984558,
#     'is_filler': False},
#    {'word': 'in',
#     'start': 17.62,
#     'end': 18.04,
#     'duration': 0.41999999999999815,
#     'confidence': 0.8526275753974915,
#     'is_filler': False},
#    {'word': 'a',
#     'start': 18.04,
#     'end': 18.18,
#     'duration': 0.14000000000000057,
#     'confidence': 0.6804933547973633,
#     'is_filler': False},
#    {'word': 'corner,',
#     'start': 18.18,
#     'end': 18.48,
#     'duration': 0.3000000000000007,
#     'confidence': 0.9991335272789001,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 19.0,
#     'end': 19.22,
#     'duration': 0.21999999999999886,
#     'confidence': 0.9552456140518188,
#     'is_filler': False},
#    {'word': 'man',
#     'start': 19.22,
#     'end': 19.48,
#     'duration': 0.26000000000000156,
#     'confidence': 0.6790711283683777,
#     'is_filler': False},
#    {'word': 'and',
#     'start': 19.48,
#     'end': 19.78,
#     'duration': 0.3000000000000007,
#     'confidence': 0.9892637133598328,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 19.78,
#     'end': 19.92,
#     'duration': 0.14000000000000057,
#     'confidence': 0.566773533821106,
#     'is_filler': False},
#    {'word': 'woman',
#     'start': 19.92,
#     'end': 20.12,
#     'duration': 0.1999999999999993,
#     'confidence': 0.8988024592399597,
#     'is_filler': False},
#    {'word': 'bumped',
#     'start': 20.12,
#     'end': 20.52,
#     'duration': 0.3999999999999986,
#     'confidence': 0.9530269503593445,
#     'is_filler': False},
#    {'word': 'into',
#     'start': 20.52,
#     'end': 20.96,
#     'duration': 0.4400000000000013,
#     'confidence': 0.9956542253494263,
#     'is_filler': False},
#    {'word': 'with',
#     'start': 20.96,
#     'end': 21.32,
#     'duration': 0.35999999999999943,
#     'confidence': 0.8041362166404724,
#     'is_filler': False},
#    {'word': 'each',
#     'start': 21.32,
#     'end': 21.54,
#     'duration': 0.21999999999999886,
#     'confidence': 0.586260974407196,
#     'is_filler': False},
#    {'word': 'other',
#     'start': 21.54,
#     'end': 21.88,
#     'duration': 0.33999999999999986,
#     'confidence': 0.9913199543952942,
#     'is_filler': False},
#    {'word': 'and',
#     'start': 21.88,
#     'end': 22.5,
#     'duration': 0.620000000000001,
#     'confidence': 0.8446270823478699,
#     'is_filler': False},
#    {'word': 'they',
#     'start': 22.5,
#     'end': 22.7,
#     'duration': 0.1999999999999993,
#     'confidence': 0.9944011569023132,
#     'is_filler': False},
#    {'word': 'just',
#     'start': 22.7,
#     'end': 23.0,
#     'duration': 0.3000000000000007,
#     'confidence': 0.9970767498016357,
#     'is_filler': False},
#    {'word': 'fold',
#     'start': 23.0,
#     'end': 23.22,
#     'duration': 0.21999999999999886,
#     'confidence': 0.30070117115974426,
#     'is_filler': False},
#    {'word': 'down.',
#     'start': 23.22,
#     'end': 23.74,
#     'duration': 0.5199999999999996,
#     'confidence': 0.9210067987442017,
#     'is_filler': False},
#    {'word': 'And',
#     'start': 24.5,
#     'end': 25.26,
#     'duration': 0.7600000000000016,
#     'confidence': 0.9416307806968689,
#     'is_filler': False},
#    {'word': 'since',
#     'start': 25.26,
#     'end': 26.16,
#     'duration': 0.8999999999999986,
#     'confidence': 0.9731159806251526,
#     'is_filler': False},
#    {'word': 'their',
#     'start': 26.16,
#     'end': 26.74,
#     'duration': 0.5799999999999983,
#     'confidence': 0.8213854432106018,
#     'is_filler': False},
#    {'word': 'cases',
#     'start': 26.74,
#     'end': 27.22,
#     'duration': 0.4800000000000004,
#     'confidence': 0.9913267493247986,
#     'is_filler': False},
#    {'word': 'are',
#     'start': 27.22,
#     'end': 27.58,
#     'duration': 0.35999999999999943,
#     'confidence': 0.9972672462463379,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 27.58,
#     'end': 27.74,
#     'duration': 0.16000000000000014,
#     'confidence': 0.34571993350982666,
#     'is_filler': False},
#    {'word': 'same.',
#     'start': 27.74,
#     'end': 28.04,
#     'duration': 0.3000000000000007,
#     'confidence': 0.8935257196426392,
#     'is_filler': False},
#    {'word': 'They',
#     'start': 28.92,
#     'end': 29.08,
#     'duration': 0.1599999999999966,
#     'confidence': 0.8881548047065735,
#     'is_filler': False},
#    {'word': "didn't",
#     'start': 29.08,
#     'end': 29.6,
#     'duration': 0.5200000000000031,
#     'confidence': 0.9707527756690979,
#     'is_filler': False},
#    {'word': 'pay',
#     'start': 29.6,
#     'end': 29.88,
#     'duration': 0.2799999999999976,
#     'confidence': 0.9960479140281677,
#     'is_filler': False},
#    {'word': 'attention',
#     'start': 29.88,
#     'end': 30.5,
#     'duration': 0.620000000000001,
#     'confidence': 0.9825600981712341,
#     'is_filler': False},
#    {'word': 'to',
#     'start': 30.5,
#     'end': 30.84,
#     'duration': 0.33999999999999986,
#     'confidence': 0.9914205074310303,
#     'is_filler': False},
#    {'word': 'that',
#     'start': 30.84,
#     'end': 31.06,
#     'duration': 0.21999999999999886,
#     'confidence': 0.9642897248268127,
#     'is_filler': False},
#    {'word': 'so',
#     'start': 31.06,
#     'end': 31.52,
#     'duration': 0.46000000000000085,
#     'confidence': 0.4170413315296173,
#     'is_filler': False},
#    {'word': 'they',
#     'start': 31.52,
#     'end': 31.8,
#     'duration': 0.28000000000000114,
#     'confidence': 0.9814693927764893,
#     'is_filler': False},
#    {'word': 'just',
#     'start': 31.8,
#     'end': 32.2,
#     'duration': 0.40000000000000213,
#     'confidence': 0.9859369397163391,
#     'is_filler': False},
#    {'word': 'grab',
#     'start': 32.2,
#     'end': 32.74,
#     'duration': 0.5399999999999991,
#     'confidence': 0.5750173330307007,
#     'is_filler': False},
#    {'word': 'one',
#     'start': 32.74,
#     'end': 33.24,
#     'duration': 0.5,
#     'confidence': 0.9920685291290283,
#     'is_filler': False},
#    {'word': 'and',
#     'start': 33.24,
#     'end': 33.94,
#     'duration': 0.6999999999999957,
#     'confidence': 0.9704400300979614,
#     'is_filler': False},
#    {'word': 'go',
#     'start': 33.94,
#     'end': 34.24,
#     'duration': 0.30000000000000426,
#     'confidence': 0.9945124387741089,
#     'is_filler': False},
#    {'word': 'to',
#     'start': 34.24,
#     'end': 34.56,
#     'duration': 0.3200000000000003,
#     'confidence': 0.9613264799118042,
#     'is_filler': False},
#    {'word': 'their',
#     'start': 34.56,
#     'end': 34.82,
#     'duration': 0.259999999999998,
#     'confidence': 0.9631791114807129,
#     'is_filler': False},
#    {'word': 'destination.',
#     'start': 34.82,
#     'end': 37.02,
#     'duration': 2.200000000000003,
#     'confidence': 0.6369971036911011,
#     'is_filler': False},
#    {'word': 'Oh,',
#     'start': 38.02,
#     'end': 38.44,
#     'duration': 0.4199999999999946,
#     'confidence': 0.5438238382339478,
#     'is_filler': False},
#    {'word': 'go',
#     'start': 38.5,
#     'end': 38.68,
#     'duration': 0.17999999999999972,
#     'confidence': 0.9694653153419495,
#     'is_filler': False},
#    {'word': 'to',
#     'start': 38.68,
#     'end': 38.86,
#     'duration': 0.17999999999999972,
#     'confidence': 0.9940186738967896,
#     'is_filler': False},
#    {'word': 'their',
#     'start': 38.86,
#     'end': 39.06,
#     'duration': 0.20000000000000284,
#     'confidence': 0.9902867078781128,
#     'is_filler': False},
#    {'word': 'home',
#     'start': 39.06,
#     'end': 39.38,
#     'duration': 0.3200000000000003,
#     'confidence': 0.9945525527000427,
#     'is_filler': False},
#    {'word': 'and',
#     'start': 39.38,
#     'end': 39.92,
#     'duration': 0.5399999999999991,
#     'confidence': 0.4435080587863922,
#     'is_filler': False},
#    {'word': 'maybe',
#     'start': 39.92,
#     'end': 40.18,
#     'duration': 0.259999999999998,
#     'confidence': 0.9853109121322632,
#     'is_filler': False},
#    {'word': 'their',
#     'start': 40.18,
#     'end': 40.68,
#     'duration': 0.5,
#     'confidence': 0.5384760499000549,
#     'is_filler': False},
#    {'word': 'office.',
#     'start': 40.68,
#     'end': 41.14,
#     'duration': 0.46000000000000085,
#     'confidence': 0.9977114200592041,
#     'is_filler': False},
#    {'word': 'But',
#     'start': 41.74,
#     'end': 41.82,
#     'duration': 0.0799999999999983,
#     'confidence': 0.9563401937484741,
#     'is_filler': False},
#    {'word': 'when',
#     'start': 41.82,
#     'end': 42.4,
#     'duration': 0.5799999999999983,
#     'confidence': 0.8258316516876221,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 42.4,
#     'end': 43.04,
#     'duration': 0.6400000000000006,
#     'confidence': 0.9597505927085876,
#     'is_filler': False},
#    {'word': 'man',
#     'start': 43.04,
#     'end': 43.3,
#     'duration': 0.259999999999998,
#     'confidence': 0.7400091290473938,
#     'is_filler': False},
#    {'word': 'around',
#     'start': 43.3,
#     'end': 43.92,
#     'duration': 0.6200000000000045,
#     'confidence': 0.9670640826225281,
#     'is_filler': False},
#    {'word': 'his',
#     'start': 43.92,
#     'end': 44.4,
#     'duration': 0.4799999999999969,
#     'confidence': 0.9916852712631226,
#     'is_filler': False},
#    {'word': 'office,',
#     'start': 44.4,
#     'end': 45.24,
#     'duration': 0.8400000000000034,
#     'confidence': 0.9943299293518066,
#     'is_filler': False},
#    {'word': 'he',
#     'start': 45.64,
#     'end': 45.92,
#     'duration': 0.28000000000000114,
#     'confidence': 0.9946132302284241,
#     'is_filler': False},
#    {'word': 'opened',
#     'start': 45.92,
#     'end': 46.28,
#     'duration': 0.35999999999999943,
#     'confidence': 0.9746213555335999,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 46.28,
#     'end': 46.72,
#     'duration': 0.4399999999999977,
#     'confidence': 0.9239219427108765,
#     'is_filler': False},
#    {'word': 'case',
#     'start': 46.72,
#     'end': 47.24,
#     'duration': 0.5200000000000031,
#     'confidence': 0.9816374182701111,
#     'is_filler': False},
#    {'word': 'and',
#     'start': 47.24,
#     'end': 47.64,
#     'duration': 0.3999999999999986,
#     'confidence': 0.9768301248550415,
#     'is_filler': False},
#    {'word': 'found',
#     'start': 47.64,
#     'end': 47.9,
#     'duration': 0.259999999999998,
#     'confidence': 0.9698450565338135,
#     'is_filler': False},
#    {'word': 'out',
#     'start': 47.9,
#     'end': 48.22,
#     'duration': 0.3200000000000003,
#     'confidence': 0.9714595079421997,
#     'is_filler': False},
#    {'word': 'that',
#     'start': 48.22,
#     'end': 48.58,
#     'duration': 0.35999999999999943,
#     'confidence': 0.9582437872886658,
#     'is_filler': False},
#    {'word': 'this',
#     'start': 48.58,
#     'end': 49.4,
#     'duration': 0.8200000000000003,
#     'confidence': 0.9671655893325806,
#     'is_filler': False},
#    {'word': 'case',
#     'start': 49.4,
#     'end': 49.68,
#     'duration': 0.28000000000000114,
#     'confidence': 0.9973282814025879,
#     'is_filler': False},
#    {'word': 'belongs',
#     'start': 49.68,
#     'end': 50.22,
#     'duration': 0.5399999999999991,
#     'confidence': 0.8594396710395813,
#     'is_filler': False},
#    {'word': 'to',
#     'start': 50.22,
#     'end': 50.68,
#     'duration': 0.46000000000000085,
#     'confidence': 0.9992870688438416,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 50.68,
#     'end': 50.98,
#     'duration': 0.29999999999999716,
#     'confidence': 0.9953309893608093,
#     'is_filler': False},
#    {'word': 'woman.',
#     'start': 50.98,
#     'end': 51.44,
#     'duration': 0.46000000000000085,
#     'confidence': 0.6043310165405273,
#     'is_filler': False},
#    {'word': 'And',
#     'start': 52.06,
#     'end': 52.28,
#     'duration': 0.21999999999999886,
#     'confidence': 0.96584153175354,
#     'is_filler': False},
#    {'word': 'when',
#     'start': 52.28,
#     'end': 52.5,
#     'duration': 0.21999999999999886,
#     'confidence': 0.9848061203956604,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 52.5,
#     'end': 52.66,
#     'duration': 0.1599999999999966,
#     'confidence': 0.9873849153518677,
#     'is_filler': False},
#    {'word': 'woman',
#     'start': 52.66,
#     'end': 53.44,
#     'duration': 0.7800000000000011,
#     'confidence': 0.9484162330627441,
#     'is_filler': False},
#    {'word': 'went',
#     'start': 53.44,
#     'end': 54.06,
#     'duration': 0.6200000000000045,
#     'confidence': 0.9979391694068909,
#     'is_filler': False},
#    {'word': 'back',
#     'start': 54.06,
#     'end': 54.54,
#     'duration': 0.4799999999999969,
#     'confidence': 0.9954000115394592,
#     'is_filler': False},
#    {'word': 'to',
#     'start': 54.54,
#     'end': 55.12,
#     'duration': 0.5799999999999983,
#     'confidence': 0.9965600371360779,
#     'is_filler': False},
#    {'word': 'his',
#     'start': 55.12,
#     'end': 55.46,
#     'duration': 0.3400000000000034,
#     'confidence': 0.9924445748329163,
#     'is_filler': False},
#    {'word': 'home,',
#     'start': 55.46,
#     'end': 55.92,
#     'duration': 0.46000000000000085,
#     'confidence': 0.9906736016273499,
#     'is_filler': False},
#    {'word': 'she',
#     'start': 55.92,
#     'end': 56.86,
#     'duration': 0.9399999999999977,
#     'confidence': 0.37503495812416077,
#     'is_filler': False},
#    {'word': 'found',
#     'start': 56.86,
#     'end': 57.18,
#     'duration': 0.3200000000000003,
#     'confidence': 0.7988777756690979,
#     'is_filler': False},
#    {'word': 'to',
#     'start': 57.18,
#     'end': 58.34,
#     'duration': 1.1600000000000037,
#     'confidence': 0.4960068166255951,
#     'is_filler': False},
#    {'word': 'her',
#     'start': 58.34,
#     'end': 58.6,
#     'duration': 0.259999999999998,
#     'confidence': 0.9683752655982971,
#     'is_filler': False},
#    {'word': 'home',
#     'start': 58.6,
#     'end': 58.94,
#     'duration': 0.3399999999999963,
#     'confidence': 0.9911103248596191,
#     'is_filler': False},
#    {'word': 'and',
#     'start': 58.94,
#     'end': 59.5,
#     'duration': 0.5600000000000023,
#     'confidence': 0.7491108775138855,
#     'is_filler': False},
#    {'word': 'she',
#     'start': 59.5,
#     'end': 60.42,
#     'duration': 0.9200000000000017,
#     'confidence': 0.9839230179786682,
#     'is_filler': False},
#    {'word': 'found',
#     'start': 60.42,
#     'end': 60.76,
#     'duration': 0.3399999999999963,
#     'confidence': 0.9932479858398438,
#     'is_filler': False},
#    {'word': 'out',
#     'start': 60.76,
#     'end': 61.06,
#     'duration': 0.30000000000000426,
#     'confidence': 0.9609400629997253,
#     'is_filler': False},
#    {'word': 'that',
#     'start': 61.06,
#     'end': 61.38,
#     'duration': 0.3200000000000003,
#     'confidence': 0.8730565309524536,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 61.38,
#     'end': 62.04,
#     'duration': 0.6599999999999966,
#     'confidence': 0.9812201261520386,
#     'is_filler': False},
#    {'word': 'case',
#     'start': 62.04,
#     'end': 62.36,
#     'duration': 0.3200000000000003,
#     'confidence': 0.9947027564048767,
#     'is_filler': False},
#    {'word': 'belongs',
#     'start': 62.36,
#     'end': 63.42,
#     'duration': 1.0600000000000023,
#     'confidence': 0.9767308235168457,
#     'is_filler': False},
#    {'word': 'to',
#     'start': 63.42,
#     'end': 63.88,
#     'duration': 0.46000000000000085,
#     'confidence': 0.9991782307624817,
#     'is_filler': False},
#    {'word': 'them.',
#     'start': 63.88,
#     'end': 64.14,
#     'duration': 0.259999999999998,
#     'confidence': 0.798069417476654,
#     'is_filler': False},
#    {'word': 'So',
#     'start': 64.54,
#     'end': 65.16,
#     'duration': 0.6199999999999903,
#     'confidence': 0.8074514865875244,
#     'is_filler': False},
#    {'word': "that's",
#     'start': 65.16,
#     'end': 65.58,
#     'duration': 0.4200000000000017,
#     'confidence': 0.9067075550556183,
#     'is_filler': False},
#    {'word': 'a',
#     'start': 65.58,
#     'end': 65.66,
#     'duration': 0.0799999999999983,
#     'confidence': 0.9407972097396851,
#     'is_filler': False},
#    {'word': 'mistake.',
#     'start': 65.66,
#     'end': 66.04,
#     'duration': 0.38000000000000966,
#     'confidence': 0.990687906742096,
#     'is_filler': False}],
#   'words_timestamps_cleaned': [{'word': 'Long,',
#     'start': 0.0,
#     'end': 0.28,
#     'duration': 0.28,
#     'confidence': 0.07641933858394623,
#     'is_filler': False},
#    {'word': 'long',
#     'start': 0.48,
#     'end': 0.64,
#     'duration': 0.16000000000000003,
#     'confidence': 0.9759964942932129,
#     'is_filler': False},
#    {'word': 'ago',
#     'start': 0.64,
#     'end': 1.16,
#     'duration': 0.5199999999999999,
#     'confidence': 0.955901563167572,
#     'is_filler': False},
#    {'word': 'in',
#     'start': 1.16,
#     'end': 1.76,
#     'duration': 0.6000000000000001,
#     'confidence': 0.6517712473869324,
#     'is_filler': False},
#    {'word': 'a',
#     'start': 1.76,
#     'end': 1.9,
#     'duration': 0.1399999999999999,
#     'confidence': 0.9493395090103149,
#     'is_filler': False},
#    {'word': 'really',
#     'start': 1.9,
#     'end': 2.2,
#     'duration': 0.30000000000000027,
#     'confidence': 0.83961421251297,
#     'is_filler': False},
#    {'word': 'big',
#     'start': 2.2,
#     'end': 2.52,
#     'duration': 0.31999999999999984,
#     'confidence': 0.992954432964325,
#     'is_filler': False},
#    {'word': 'city',
#     'start': 2.52,
#     'end': 3.04,
#     'duration': 0.52,
#     'confidence': 0.9963235855102539,
#     'is_filler': False},
#    {'word': 'and',
#     'start': 3.04,
#     'end': 4.02,
#     'duration': 0.9799999999999995,
#     'confidence': 0.6349655389785767,
#     'is_filler': False},
#    {'word': 'in',
#     'start': 4.02,
#     'end': 4.26,
#     'duration': 0.2400000000000002,
#     'confidence': 0.9241474270820618,
#     'is_filler': False},
#    {'word': 'a',
#     'start': 4.26,
#     'end': 4.42,
#     'duration': 0.16000000000000014,
#     'confidence': 0.5630697011947632,
#     'is_filler': False},
#    {'word': 'corner',
#     'start': 4.42,
#     'end': 5.0,
#     'duration': 0.5800000000000001,
#     'confidence': 0.9991878867149353,
#     'is_filler': False},
#    {'word': 'of',
#     'start': 5.0,
#     'end': 5.46,
#     'duration': 0.45999999999999996,
#     'confidence': 0.9919318556785583,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 5.46,
#     'end': 5.72,
#     'duration': 0.2599999999999998,
#     'confidence': 0.9847453236579895,
#     'is_filler': False},
#    {'word': 'building,',
#     'start': 5.72,
#     'end': 6.22,
#     'duration': 0.5,
#     'confidence': 0.9915297031402588,
#     'is_filler': False},
#    {'word': 'a',
#     'start': 6.6,
#     'end': 7.12,
#     'duration': 0.5200000000000005,
#     'confidence': 0.8921689391136169,
#     'is_filler': False},
#    {'word': 'man',
#     'start': 7.12,
#     'end': 7.44,
#     'duration': 0.3200000000000003,
#     'confidence': 0.9884127974510193,
#     'is_filler': False},
#    {'word': 'and',
#     'start': 7.44,
#     'end': 8.0,
#     'duration': 0.5599999999999996,
#     'confidence': 0.9644271731376648,
#     'is_filler': False},
#    {'word': 'a',
#     'start': 8.0,
#     'end': 8.24,
#     'duration': 0.2400000000000002,
#     'confidence': 0.6371814608573914,
#     'is_filler': False},
#    {'word': 'woman',
#     'start': 8.24,
#     'end': 8.5,
#     'duration': 0.2599999999999998,
#     'confidence': 0.8666236996650696,
#     'is_filler': False},
#    {'word': 'just',
#     'start': 8.5,
#     'end': 9.46,
#     'duration': 0.9600000000000009,
#     'confidence': 0.9478781819343567,
#     'is_filler': False},
#    {'word': 'want',
#     'start': 9.46,
#     'end': 9.96,
#     'duration': 0.5,
#     'confidence': 0.48793306946754456,
#     'is_filler': False},
#    {'word': 'to',
#     'start': 9.96,
#     'end': 10.2,
#     'duration': 0.23999999999999844,
#     'confidence': 0.982209324836731,
#     'is_filler': False},
#    {'word': 'go',
#     'start': 10.2,
#     'end': 10.8,
#     'duration': 0.6000000000000014,
#     'confidence': 0.9909919500350952,
#     'is_filler': False},
#    {'word': 'to',
#     'start': 10.8,
#     'end': 11.22,
#     'duration': 0.41999999999999993,
#     'confidence': 0.9805959463119507,
#     'is_filler': False},
#    {'word': 'their',
#     'start': 11.22,
#     'end': 11.58,
#     'duration': 0.35999999999999943,
#     'confidence': 0.9881580471992493,
#     'is_filler': False},
#    {'word': 'destination',
#     'start': 11.58,
#     'end': 12.82,
#     'duration': 1.2400000000000002,
#     'confidence': 0.9958012700080872,
#     'is_filler': False},
#    {'word': 'and',
#     'start': 12.82,
#     'end': 13.58,
#     'duration': 0.7599999999999998,
#     'confidence': 0.6094791889190674,
#     'is_filler': False},
#    {'word': 'they',
#     'start': 13.58,
#     'end': 13.84,
#     'duration': 0.2599999999999998,
#     'confidence': 0.9882104396820068,
#     'is_filler': False},
#    {'word': 'both',
#     'start': 13.84,
#     'end': 14.26,
#     'duration': 0.41999999999999993,
#     'confidence': 0.9969285130500793,
#     'is_filler': False},
#    {'word': 'carry',
#     'start': 14.26,
#     'end': 14.66,
#     'duration': 0.40000000000000036,
#     'confidence': 0.6884579062461853,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 14.66,
#     'end': 14.9,
#     'duration': 0.2400000000000002,
#     'confidence': 0.9774173498153687,
#     'is_filler': False},
#    {'word': 'same',
#     'start': 14.9,
#     'end': 15.26,
#     'duration': 0.35999999999999943,
#     'confidence': 0.9938567280769348,
#     'is_filler': False},
#    {'word': 'cases.',
#     'start': 15.26,
#     'end': 15.78,
#     'duration': 0.5199999999999996,
#     'confidence': 0.9557271003723145,
#     'is_filler': False},
#    {'word': 'And',
#     'start': 16.5,
#     'end': 17.04,
#     'duration': 0.5399999999999991,
#     'confidence': 0.630698025226593,
#     'is_filler': False},
#    {'word': 'but',
#     'start': 17.04,
#     'end': 17.2,
#     'duration': 0.16000000000000014,
#     'confidence': 0.7018191814422607,
#     'is_filler': False},
#    {'word': 'suddenly',
#     'start': 17.2,
#     'end': 17.62,
#     'duration': 0.4200000000000017,
#     'confidence': 0.6018807291984558,
#     'is_filler': False},
#    {'word': 'in',
#     'start': 17.62,
#     'end': 18.04,
#     'duration': 0.41999999999999815,
#     'confidence': 0.8526275753974915,
#     'is_filler': False},
#    {'word': 'a',
#     'start': 18.04,
#     'end': 18.18,
#     'duration': 0.14000000000000057,
#     'confidence': 0.6804933547973633,
#     'is_filler': False},
#    {'word': 'corner,',
#     'start': 18.18,
#     'end': 18.48,
#     'duration': 0.3000000000000007,
#     'confidence': 0.9991335272789001,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 19.0,
#     'end': 19.22,
#     'duration': 0.21999999999999886,
#     'confidence': 0.9552456140518188,
#     'is_filler': False},
#    {'word': 'man',
#     'start': 19.22,
#     'end': 19.48,
#     'duration': 0.26000000000000156,
#     'confidence': 0.6790711283683777,
#     'is_filler': False},
#    {'word': 'and',
#     'start': 19.48,
#     'end': 19.78,
#     'duration': 0.3000000000000007,
#     'confidence': 0.9892637133598328,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 19.78,
#     'end': 19.92,
#     'duration': 0.14000000000000057,
#     'confidence': 0.566773533821106,
#     'is_filler': False},
#    {'word': 'woman',
#     'start': 19.92,
#     'end': 20.12,
#     'duration': 0.1999999999999993,
#     'confidence': 0.8988024592399597,
#     'is_filler': False},
#    {'word': 'bumped',
#     'start': 20.12,
#     'end': 20.52,
#     'duration': 0.3999999999999986,
#     'confidence': 0.9530269503593445,
#     'is_filler': False},
#    {'word': 'into',
#     'start': 20.52,
#     'end': 20.96,
#     'duration': 0.4400000000000013,
#     'confidence': 0.9956542253494263,
#     'is_filler': False},
#    {'word': 'with',
#     'start': 20.96,
#     'end': 21.32,
#     'duration': 0.35999999999999943,
#     'confidence': 0.8041362166404724,
#     'is_filler': False},
#    {'word': 'each',
#     'start': 21.32,
#     'end': 21.54,
#     'duration': 0.21999999999999886,
#     'confidence': 0.586260974407196,
#     'is_filler': False},
#    {'word': 'other',
#     'start': 21.54,
#     'end': 21.88,
#     'duration': 0.33999999999999986,
#     'confidence': 0.9913199543952942,
#     'is_filler': False},
#    {'word': 'and',
#     'start': 21.88,
#     'end': 22.5,
#     'duration': 0.620000000000001,
#     'confidence': 0.8446270823478699,
#     'is_filler': False},
#    {'word': 'they',
#     'start': 22.5,
#     'end': 22.7,
#     'duration': 0.1999999999999993,
#     'confidence': 0.9944011569023132,
#     'is_filler': False},
#    {'word': 'just',
#     'start': 22.7,
#     'end': 23.0,
#     'duration': 0.3000000000000007,
#     'confidence': 0.9970767498016357,
#     'is_filler': False},
#    {'word': 'fold',
#     'start': 23.0,
#     'end': 23.22,
#     'duration': 0.21999999999999886,
#     'confidence': 0.30070117115974426,
#     'is_filler': False},
#    {'word': 'down.',
#     'start': 23.22,
#     'end': 23.74,
#     'duration': 0.5199999999999996,
#     'confidence': 0.9210067987442017,
#     'is_filler': False},
#    {'word': 'And',
#     'start': 24.5,
#     'end': 25.26,
#     'duration': 0.7600000000000016,
#     'confidence': 0.9416307806968689,
#     'is_filler': False},
#    {'word': 'since',
#     'start': 25.26,
#     'end': 26.16,
#     'duration': 0.8999999999999986,
#     'confidence': 0.9731159806251526,
#     'is_filler': False},
#    {'word': 'their',
#     'start': 26.16,
#     'end': 26.74,
#     'duration': 0.5799999999999983,
#     'confidence': 0.8213854432106018,
#     'is_filler': False},
#    {'word': 'cases',
#     'start': 26.74,
#     'end': 27.22,
#     'duration': 0.4800000000000004,
#     'confidence': 0.9913267493247986,
#     'is_filler': False},
#    {'word': 'are',
#     'start': 27.22,
#     'end': 27.58,
#     'duration': 0.35999999999999943,
#     'confidence': 0.9972672462463379,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 27.58,
#     'end': 27.74,
#     'duration': 0.16000000000000014,
#     'confidence': 0.34571993350982666,
#     'is_filler': False},
#    {'word': 'same.',
#     'start': 27.74,
#     'end': 28.04,
#     'duration': 0.3000000000000007,
#     'confidence': 0.8935257196426392,
#     'is_filler': False},
#    {'word': 'They',
#     'start': 28.92,
#     'end': 29.08,
#     'duration': 0.1599999999999966,
#     'confidence': 0.8881548047065735,
#     'is_filler': False},
#    {'word': "didn't",
#     'start': 29.08,
#     'end': 29.6,
#     'duration': 0.5200000000000031,
#     'confidence': 0.9707527756690979,
#     'is_filler': False},
#    {'word': 'pay',
#     'start': 29.6,
#     'end': 29.88,
#     'duration': 0.2799999999999976,
#     'confidence': 0.9960479140281677,
#     'is_filler': False},
#    {'word': 'attention',
#     'start': 29.88,
#     'end': 30.5,
#     'duration': 0.620000000000001,
#     'confidence': 0.9825600981712341,
#     'is_filler': False},
#    {'word': 'to',
#     'start': 30.5,
#     'end': 30.84,
#     'duration': 0.33999999999999986,
#     'confidence': 0.9914205074310303,
#     'is_filler': False},
#    {'word': 'that',
#     'start': 30.84,
#     'end': 31.06,
#     'duration': 0.21999999999999886,
#     'confidence': 0.9642897248268127,
#     'is_filler': False},
#    {'word': 'so',
#     'start': 31.06,
#     'end': 31.52,
#     'duration': 0.46000000000000085,
#     'confidence': 0.4170413315296173,
#     'is_filler': False},
#    {'word': 'they',
#     'start': 31.52,
#     'end': 31.8,
#     'duration': 0.28000000000000114,
#     'confidence': 0.9814693927764893,
#     'is_filler': False},
#    {'word': 'just',
#     'start': 31.8,
#     'end': 32.2,
#     'duration': 0.40000000000000213,
#     'confidence': 0.9859369397163391,
#     'is_filler': False},
#    {'word': 'grab',
#     'start': 32.2,
#     'end': 32.74,
#     'duration': 0.5399999999999991,
#     'confidence': 0.5750173330307007,
#     'is_filler': False},
#    {'word': 'one',
#     'start': 32.74,
#     'end': 33.24,
#     'duration': 0.5,
#     'confidence': 0.9920685291290283,
#     'is_filler': False},
#    {'word': 'and',
#     'start': 33.24,
#     'end': 33.94,
#     'duration': 0.6999999999999957,
#     'confidence': 0.9704400300979614,
#     'is_filler': False},
#    {'word': 'go',
#     'start': 33.94,
#     'end': 34.24,
#     'duration': 0.30000000000000426,
#     'confidence': 0.9945124387741089,
#     'is_filler': False},
#    {'word': 'to',
#     'start': 34.24,
#     'end': 34.56,
#     'duration': 0.3200000000000003,
#     'confidence': 0.9613264799118042,
#     'is_filler': False},
#    {'word': 'their',
#     'start': 34.56,
#     'end': 34.82,
#     'duration': 0.259999999999998,
#     'confidence': 0.9631791114807129,
#     'is_filler': False},
#    {'word': 'destination.',
#     'start': 34.82,
#     'end': 37.02,
#     'duration': 2.200000000000003,
#     'confidence': 0.6369971036911011,
#     'is_filler': False},
#    {'word': 'Oh,',
#     'start': 38.02,
#     'end': 38.44,
#     'duration': 0.4199999999999946,
#     'confidence': 0.5438238382339478,
#     'is_filler': False},
#    {'word': 'go',
#     'start': 38.5,
#     'end': 38.68,
#     'duration': 0.17999999999999972,
#     'confidence': 0.9694653153419495,
#     'is_filler': False},
#    {'word': 'to',
#     'start': 38.68,
#     'end': 38.86,
#     'duration': 0.17999999999999972,
#     'confidence': 0.9940186738967896,
#     'is_filler': False},
#    {'word': 'their',
#     'start': 38.86,
#     'end': 39.06,
#     'duration': 0.20000000000000284,
#     'confidence': 0.9902867078781128,
#     'is_filler': False},
#    {'word': 'home',
#     'start': 39.06,
#     'end': 39.38,
#     'duration': 0.3200000000000003,
#     'confidence': 0.9945525527000427,
#     'is_filler': False},
#    {'word': 'and',
#     'start': 39.38,
#     'end': 39.92,
#     'duration': 0.5399999999999991,
#     'confidence': 0.4435080587863922,
#     'is_filler': False},
#    {'word': 'maybe',
#     'start': 39.92,
#     'end': 40.18,
#     'duration': 0.259999999999998,
#     'confidence': 0.9853109121322632,
#     'is_filler': False},
#    {'word': 'their',
#     'start': 40.18,
#     'end': 40.68,
#     'duration': 0.5,
#     'confidence': 0.5384760499000549,
#     'is_filler': False},
#    {'word': 'office.',
#     'start': 40.68,
#     'end': 41.14,
#     'duration': 0.46000000000000085,
#     'confidence': 0.9977114200592041,
#     'is_filler': False},
#    {'word': 'But',
#     'start': 41.74,
#     'end': 41.82,
#     'duration': 0.0799999999999983,
#     'confidence': 0.9563401937484741,
#     'is_filler': False},
#    {'word': 'when',
#     'start': 41.82,
#     'end': 42.4,
#     'duration': 0.5799999999999983,
#     'confidence': 0.8258316516876221,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 42.4,
#     'end': 43.04,
#     'duration': 0.6400000000000006,
#     'confidence': 0.9597505927085876,
#     'is_filler': False},
#    {'word': 'man',
#     'start': 43.04,
#     'end': 43.3,
#     'duration': 0.259999999999998,
#     'confidence': 0.7400091290473938,
#     'is_filler': False},
#    {'word': 'around',
#     'start': 43.3,
#     'end': 43.92,
#     'duration': 0.6200000000000045,
#     'confidence': 0.9670640826225281,
#     'is_filler': False},
#    {'word': 'his',
#     'start': 43.92,
#     'end': 44.4,
#     'duration': 0.4799999999999969,
#     'confidence': 0.9916852712631226,
#     'is_filler': False},
#    {'word': 'office,',
#     'start': 44.4,
#     'end': 45.24,
#     'duration': 0.8400000000000034,
#     'confidence': 0.9943299293518066,
#     'is_filler': False},
#    {'word': 'he',
#     'start': 45.64,
#     'end': 45.92,
#     'duration': 0.28000000000000114,
#     'confidence': 0.9946132302284241,
#     'is_filler': False},
#    {'word': 'opened',
#     'start': 45.92,
#     'end': 46.28,
#     'duration': 0.35999999999999943,
#     'confidence': 0.9746213555335999,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 46.28,
#     'end': 46.72,
#     'duration': 0.4399999999999977,
#     'confidence': 0.9239219427108765,
#     'is_filler': False},
#    {'word': 'case',
#     'start': 46.72,
#     'end': 47.24,
#     'duration': 0.5200000000000031,
#     'confidence': 0.9816374182701111,
#     'is_filler': False},
#    {'word': 'and',
#     'start': 47.24,
#     'end': 47.64,
#     'duration': 0.3999999999999986,
#     'confidence': 0.9768301248550415,
#     'is_filler': False},
#    {'word': 'found',
#     'start': 47.64,
#     'end': 47.9,
#     'duration': 0.259999999999998,
#     'confidence': 0.9698450565338135,
#     'is_filler': False},
#    {'word': 'out',
#     'start': 47.9,
#     'end': 48.22,
#     'duration': 0.3200000000000003,
#     'confidence': 0.9714595079421997,
#     'is_filler': False},
#    {'word': 'that',
#     'start': 48.22,
#     'end': 48.58,
#     'duration': 0.35999999999999943,
#     'confidence': 0.9582437872886658,
#     'is_filler': False},
#    {'word': 'this',
#     'start': 48.58,
#     'end': 49.4,
#     'duration': 0.8200000000000003,
#     'confidence': 0.9671655893325806,
#     'is_filler': False},
#    {'word': 'case',
#     'start': 49.4,
#     'end': 49.68,
#     'duration': 0.28000000000000114,
#     'confidence': 0.9973282814025879,
#     'is_filler': False},
#    {'word': 'belongs',
#     'start': 49.68,
#     'end': 50.22,
#     'duration': 0.5399999999999991,
#     'confidence': 0.8594396710395813,
#     'is_filler': False},
#    {'word': 'to',
#     'start': 50.22,
#     'end': 50.68,
#     'duration': 0.46000000000000085,
#     'confidence': 0.9992870688438416,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 50.68,
#     'end': 50.98,
#     'duration': 0.29999999999999716,
#     'confidence': 0.9953309893608093,
#     'is_filler': False},
#    {'word': 'woman.',
#     'start': 50.98,
#     'end': 51.44,
#     'duration': 0.46000000000000085,
#     'confidence': 0.6043310165405273,
#     'is_filler': False},
#    {'word': 'And',
#     'start': 52.06,
#     'end': 52.28,
#     'duration': 0.21999999999999886,
#     'confidence': 0.96584153175354,
#     'is_filler': False},
#    {'word': 'when',
#     'start': 52.28,
#     'end': 52.5,
#     'duration': 0.21999999999999886,
#     'confidence': 0.9848061203956604,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 52.5,
#     'end': 52.66,
#     'duration': 0.1599999999999966,
#     'confidence': 0.9873849153518677,
#     'is_filler': False},
#    {'word': 'woman',
#     'start': 52.66,
#     'end': 53.44,
#     'duration': 0.7800000000000011,
#     'confidence': 0.9484162330627441,
#     'is_filler': False},
#    {'word': 'went',
#     'start': 53.44,
#     'end': 54.06,
#     'duration': 0.6200000000000045,
#     'confidence': 0.9979391694068909,
#     'is_filler': False},
#    {'word': 'back',
#     'start': 54.06,
#     'end': 54.54,
#     'duration': 0.4799999999999969,
#     'confidence': 0.9954000115394592,
#     'is_filler': False},
#    {'word': 'to',
#     'start': 54.54,
#     'end': 55.12,
#     'duration': 0.5799999999999983,
#     'confidence': 0.9965600371360779,
#     'is_filler': False},
#    {'word': 'his',
#     'start': 55.12,
#     'end': 55.46,
#     'duration': 0.3400000000000034,
#     'confidence': 0.9924445748329163,
#     'is_filler': False},
#    {'word': 'home,',
#     'start': 55.46,
#     'end': 55.92,
#     'duration': 0.46000000000000085,
#     'confidence': 0.9906736016273499,
#     'is_filler': False},
#    {'word': 'she',
#     'start': 55.92,
#     'end': 56.86,
#     'duration': 0.9399999999999977,
#     'confidence': 0.37503495812416077,
#     'is_filler': False},
#    {'word': 'found',
#     'start': 56.86,
#     'end': 57.18,
#     'duration': 0.3200000000000003,
#     'confidence': 0.7988777756690979,
#     'is_filler': False},
#    {'word': 'to',
#     'start': 57.18,
#     'end': 58.34,
#     'duration': 1.1600000000000037,
#     'confidence': 0.4960068166255951,
#     'is_filler': False},
#    {'word': 'her',
#     'start': 58.34,
#     'end': 58.6,
#     'duration': 0.259999999999998,
#     'confidence': 0.9683752655982971,
#     'is_filler': False},
#    {'word': 'home',
#     'start': 58.6,
#     'end': 58.94,
#     'duration': 0.3399999999999963,
#     'confidence': 0.9911103248596191,
#     'is_filler': False},
#    {'word': 'and',
#     'start': 58.94,
#     'end': 59.5,
#     'duration': 0.5600000000000023,
#     'confidence': 0.7491108775138855,
#     'is_filler': False},
#    {'word': 'she',
#     'start': 59.5,
#     'end': 60.42,
#     'duration': 0.9200000000000017,
#     'confidence': 0.9839230179786682,
#     'is_filler': False},
#    {'word': 'found',
#     'start': 60.42,
#     'end': 60.76,
#     'duration': 0.3399999999999963,
#     'confidence': 0.9932479858398438,
#     'is_filler': False},
#    {'word': 'out',
#     'start': 60.76,
#     'end': 61.06,
#     'duration': 0.30000000000000426,
#     'confidence': 0.9609400629997253,
#     'is_filler': False},
#    {'word': 'that',
#     'start': 61.06,
#     'end': 61.38,
#     'duration': 0.3200000000000003,
#     'confidence': 0.8730565309524536,
#     'is_filler': False},
#    {'word': 'the',
#     'start': 61.38,
#     'end': 62.04,
#     'duration': 0.6599999999999966,
#     'confidence': 0.9812201261520386,
#     'is_filler': False},
#    {'word': 'case',
#     'start': 62.04,
#     'end': 62.36,
#     'duration': 0.3200000000000003,
#     'confidence': 0.9947027564048767,
#     'is_filler': False},
#    {'word': 'belongs',
#     'start': 62.36,
#     'end': 63.42,
#     'duration': 1.0600000000000023,
#     'confidence': 0.9767308235168457,
#     'is_filler': False},
#    {'word': 'to',
#     'start': 63.42,
#     'end': 63.88,
#     'duration': 0.46000000000000085,
#     'confidence': 0.9991782307624817,
#     'is_filler': False},
#    {'word': 'them.',
#     'start': 63.88,
#     'end': 64.14,
#     'duration': 0.259999999999998,
#     'confidence': 0.798069417476654,
#     'is_filler': False},
#    {'word': 'So',
#     'start': 64.54,
#     'end': 65.16,
#     'duration': 0.6199999999999903,
#     'confidence': 0.8074514865875244,
#     'is_filler': False},
#    {'word': "that's",
#     'start': 65.16,
#     'end': 65.58,
#     'duration': 0.4200000000000017,
#     'confidence': 0.9067075550556183,
#     'is_filler': False},
#    {'word': 'a',
#     'start': 65.58,
#     'end': 65.66,
#     'duration': 0.0799999999999983,
#     'confidence': 0.9407972097396851,
#     'is_filler': False},
#    {'word': 'mistake.',
#     'start': 65.66,
#     'end': 66.04,
#     'duration': 0.38000000000000966,
#     'confidence': 0.990687906742096,
#     'is_filler': False}],
#   'segment_timestamps': [{'text': 'Long, long ago in a really big city and in a corner of the building, a man and a woman just',
#     'start': 0.0,
#     'end': 9.46,
#     'duration': 9.46,
#     'avg_word_confidence': 0.8487900034302757,
#     'contains_filler': False},
#    {'text': 'want to go to their destination and they both carry the same cases. And but suddenly in a corner,',
#     'start': 9.46,
#     'end': 18.48,
#     'duration': 9.02,
#     'avg_word_confidence': 0.8474957488085094,
#     'contains_filler': False},
#    {'text': 'the man and the woman bumped into with each other and they just fold down. And since their cases are',
#     'start': 19.0,
#     'end': 27.58,
#     'duration': 8.579999999999998,
#     'avg_word_confidence': 0.8601046964526177,
#     'contains_filler': False},
#    {'text': "the same. They didn't pay attention to that so they just grab one and go to their destination.",
#     'start': 27.58,
#     'end': 37.02,
#     'duration': 9.440000000000005,
#     'avg_word_confidence': 0.8616922315624025,
#     'contains_filler': False},
#    {'text': 'Oh, go to their home and maybe their office. But when the man around his office, he opened the case',
#     'start': 38.02,
#     'end': 47.24,
#     'duration': 9.219999999999999,
#     'avg_word_confidence': 0.8883479163050652,
#     'contains_filler': False},
#    {'text': 'and found out that this case belongs to the woman. And when the woman went back to his home,',
#     'start': 47.24,
#     'end': 55.92,
#     'duration': 8.68,
#     'avg_word_confidence': 0.9557224888550607,
#     'contains_filler': False},
#    {'text': 'she found to her home and she found out that the case belongs to them.',
#     'start': 55.92,
#     'end': 64.14,
#     'duration': 8.219999999999999,
#     'avg_word_confidence': 0.8626389980316163,
#     'contains_filler': False},
#    {'text': "So that's a mistake.",
#     'start': 64.54,
#     'end': 66.04,
#     'duration': 1.5,
#     'avg_word_confidence': 0.9114110395312309,
#     'contains_filler': False}],
#   'filler_timestamps': [{'type': 'filler',
#     'text': 'um',
#     'raw_label': 'N',
#     'start': 1.7,
#     'end': 1.74,
#     'duration': 0.040000000000000036,
#     'style': 'subtle',
#     'count': nan},
#    {'type': 'filler',
#     'text': 'uh',
#     'raw_label': 'I',
#     'start': 4.18,
#     'end': 4.2,
#     'duration': 0.020000000000000462,
#     'style': 'subtle',
#     'count': nan},
#    {'type': 'filler',
#     'text': 'uh',
#     'raw_label': 'O',
#     'start': 5.34,
#     'end': 5.36,
#     'duration': 0.020000000000000462,
#     'style': 'subtle',
#     'count': nan},
#    {'type': 'filler',
#     'text': 'uh',
#     'raw_label': 'A',
#     'start': 7.84,
#     'end': 7.86,
#     'duration': 0.020000000000000462,
#     'style': 'subtle',
#     'count': nan},
#    {'type': 'filler',
#     'text': 'uh',
#     'raw_label': 'A',
#     'start': 9.86,
#     'end': 9.88,
#     'duration': 0.02000000000000135,
#     'style': 'subtle',
#     'count': nan},
#    {'type': 'filler',
#     'text': 'uh',
#     'raw_label': 'A',
#     'start': 16.92,
#     'end': 16.96,
#     'duration': 0.03999999999999915,
#     'style': 'subtle',
#     'count': nan},
#    {'type': 'filler',
#     'text': 'uh',
#     'raw_label': 'A',
#     'start': 25.1,
#     'end': 25.14,
#     'duration': 0.03999999999999915,
#     'style': 'subtle',
#     'count': nan},
#    {'type': 'filler',
#     'text': 'uh',
#     'raw_label': 'A',
#     'start': 33.72,
#     'end': 33.76,
#     'duration': 0.03999999999999915,
#     'style': 'subtle',
#     'count': nan},
#    {'type': 'filler',
#     'text': 'um',
#     'raw_label': 'N',
#     'start': 37.26,
#     'end': 37.28,
#     'duration': 0.020000000000003126,
#     'style': 'subtle',
#     'count': nan},
#    {'type': 'filler',
#     'text': 'uh',
#     'raw_label': 'U',
#     'start': 53.22,
#     'end': 53.24,
#     'duration': 0.020000000000003126,
#     'style': 'subtle',
#     'count': nan},
#    {'type': 'filler',
#     'text': 'uh',
#     'raw_label': 'A',
#     'start': 59.32,
#     'end': 59.34,
#     'duration': 0.020000000000003126,
#     'style': 'subtle',
#     'count': nan},
#    {'type': 'filler',
#     'text': 'uh',
#     'raw_label': 'O',
#     'start': 60.9,
#     'end': 60.92,
#     'duration': 0.020000000000003126,
#     'style': 'subtle',
#     'count': nan},
#    {'type': 'filler',
#     'text': 'um',
#     'raw_label': 'M',
#     'start': 64.22,
#     'end': 64.26,
#     'duration': 0.04000000000000625,
#     'style': 'subtle',
#     'count': nan},
#    {'type': 'filler',
#     'text': 'um',
#     'raw_label': 'N',
#     'start': 64.38,
#     'end': 64.4,
#     'duration': 0.020000000000010232,
#     'style': 'subtle',
#     'count': nan}]}}

# %%
from src.llm_processing import extract_llm_annotations, aggregate_llm_metrics

llm_result = extract_llm_annotations(result["raw_transcript"])
llm_metrics = aggregate_llm_metrics(llm_result)

llm_metrics
# Out:
# {'coherence_breaks': 1,
#  'topic_relevance': True,
#  'word_choice_errors': 2,
#  'advanced_vocabulary_count': 0,
#  'complex_structures_attempted': 2,
#  'complex_structures_accurate': 0,
#  'grammar_errors': 3,
#  'meaning_blocking_error_ratio': 0.333}
