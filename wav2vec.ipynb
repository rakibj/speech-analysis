# %%
import torch
import torchaudio
from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
import soundfile as sf

# %%
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h") #Audio → numbers → shape the model expects
wav2vec = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-large-960h") #The model itself
wav2vec.eval() #Set to eval mode (we are not training)
# Out:
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Wav2Vec2ForCTC(
#   (wav2vec2): Wav2Vec2Model(
#     (feature_extractor): Wav2Vec2FeatureEncoder(
#       (conv_layers): ModuleList(
#         (0): Wav2Vec2GroupNormConvLayer(
#           (conv): Conv1d(1, 512, kernel_size=(10,), stride=(5,), bias=False)
#           (activation): GELUActivation()
#           (layer_norm): GroupNorm(512, 512, eps=1e-05, affine=True)
#         )
#         (1-4): 4 x Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(3,), stride=(2,), bias=False)
#           (activation): GELUActivation()
#         )
#         (5-6): 2 x Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(2,), stride=(2,), bias=False)
#           (activation): GELUActivation()
#         )
#       )
#     )
#     (feature_projection): Wav2Vec2FeatureProjection(
#       (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (projection): Linear(in_features=512, out_features=1024, bias=True)
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): Wav2Vec2Encoder(
#       (pos_conv_embed): Wav2Vec2PositionalConvEmbedding(
#         (conv): ParametrizedConv1d(
#           1024, 1024, kernel_size=(128,), stride=(1,), padding=(64,), groups=16
#           (parametrizations): ModuleDict(
#             (weight): ParametrizationList(
#               (0): _WeightNorm()
#             )
#           )
#         )
#         (padding): Wav2Vec2SamePadLayer()
#         (activation): GELUActivation()
#       )
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (layers): ModuleList(
#         (0-23): 24 x Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=1024, out_features=4096, bias=True)
#             (intermediate_act_fn): GELUActivation()
#             (output_dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (lm_head): Linear(in_features=1024, out_features=32, bias=True)
# )

# %%
waveform, sr = sf.read("sample2.flac", dtype="float32") # waveform: np.ndarray, sr: int, each number in waveform signifies amplitude at that time

# Convert stereo → mono
if waveform.ndim == 2:
    waveform = waveform.mean(axis=1)

waveform = torch.from_numpy(waveform) # Convert to torch tensor

# Resample to 16kHz if needed (since the model expects 16kHz audio)
if sr != 16000:
    waveform = torchaudio.functional.resample(waveform, sr, 16000)
    sr = 16000

# Prepare input for the model
inputs = processor(
    waveform.squeeze(), # Remove any extra dimensions
    sampling_rate=16000,
    return_tensors="pt", # Return PyTorch tensors
)

# Forward pass through the model
with torch.no_grad():
    logits = wav2vec(**inputs).logits # logit = time_step_1 -> [prob_sound_1, ...]

# for each time slice, choose sound with highest probability
predicted_ids = torch.argmax(logits, dim=-1)[0]
# Convert token IDs to human readable tokens
tokens = processor.tokenizer.convert_ids_to_tokens(predicted_ids.tolist())
tokens # each token is 20ms of audio that represents what was spoken
# <pad> = nothing meaningful happened in this 20ms slice
# | = word boundary
# Out:
# ['<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'B',
#  'E',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'F',
#  '<pad>',
#  'O',
#  '<pad>',
#  'R',
#  'E',
#  '<pad>',
#  '|',
#  '|',
#  'H',
#  'H',
#  'E',
#  '<pad>',
#  '|',
#  '|',
#  '<pad>',
#  'H',
#  '<pad>',
#  'A',
#  '<pad>',
#  'D',
#  '<pad>',
#  '|',
#  '|',
#  '<pad>',
#  '<pad>',
#  'T',
#  'T',
#  '<pad>',
#  'I',
#  '<pad>',
#  'M',
#  'M',
#  'E',
#  '<pad>',
#  '|',
#  '|',
#  'T',
#  'O',
#  'O',
#  '|',
#  '|',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'A',
#  '<pad>',
#  '<pad>',
#  'N',
#  'N',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'S',
#  '<pad>',
#  'W',
#  '<pad>',
#  'E',
#  'E',
#  'R',
#  'R',
#  '<pad>',
#  '<pad>',
#  '|',
#  '|',
#  '|',
#  '|',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'A',
#  '<pad>',
#  '|',
#  '|',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'M',
#  '<pad>',
#  'U',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'C',
#  'H',
#  'H',
#  '<pad>',
#  '<pad>',
#  '|',
#  '|',
#  '|',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'E',
#  'N',
#  'N',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'C',
#  '<pad>',
#  'U',
#  'U',
#  'M',
#  'M',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'B',
#  'E',
#  'E',
#  '<pad>',
#  'R',
#  '<pad>',
#  'E',
#  '<pad>',
#  'D',
#  '|',
#  '|',
#  '<pad>',
#  '<pad>',
#  'V',
#  '<pad>',
#  'E',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'R',
#  'R',
#  '<pad>',
#  '<pad>',
#  'A',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '|',
#  '|',
#  '|',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'B',
#  'B',
#  '<pad>',
#  'U',
#  '<pad>',
#  'R',
#  'R',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'S',
#  '<pad>',
#  '<pad>',
#  'T',
#  '<pad>',
#  '|',
#  '|',
#  'I',
#  'N',
#  'N',
#  '<pad>',
#  '<pad>',
#  'T',
#  'O',
#  '<pad>',
#  '|',
#  '|',
#  'T',
#  'H',
#  'E',
#  '|',
#  '|',
#  '<pad>',
#  'R',
#  'O',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'O',
#  '<pad>',
#  'M',
#  '<pad>',
#  '|',
#  '<pad>',
#  'W',
#  'I',
#  'T',
#  'H',
#  '|',
#  '|',
#  'T',
#  'H',
#  'E',
#  '|',
#  '<pad>',
#  'Q',
#  'U',
#  'U',
#  'E',
#  '<pad>',
#  '<pad>',
#  'S',
#  '<pad>',
#  '<pad>',
#  'T',
#  'I',
#  'I',
#  'O',
#  'N',
#  'N',
#  '<pad>',
#  '|',
#  '|',
#  '|',
#  '|',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'I',
#  '<pad>',
#  '|',
#  '|',
#  '<pad>',
#  '<pad>',
#  'S',
#  '<pad>',
#  '<pad>',
#  'A',
#  '<pad>',
#  'Y',
#  '<pad>',
#  '<pad>',
#  '|',
#  '|',
#  '|',
#  '|',
#  '|',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'C',
#  'A',
#  '<pad>',
#  'N',
#  '<pad>',
#  '<pad>',
#  '|',
#  '|',
#  'I',
#  '|',
#  '|',
#  '|',
#  '|',
#  '<pad>',
#  'L',
#  'E',
#  '<pad>',
#  'A',
#  '<pad>',
#  'V',
#  'E',
#  'E',
#  '|',
#  '|',
#  'T',
#  'H',
#  'E',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'S',
#  'E',
#  '|',
#  '|',
#  '<pad>',
#  'H',
#  'E',
#  'E',
#  '<pad>',
#  '<pad>',
#  'R',
#  'E',
#  'E',
#  '<pad>',
#  '|',
#  '|',
#  '|',
#  '|',
#  '|',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'T',
#  'H',
#  'H',
#  'E',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'S',
#  'E',
#  'E',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '|',
#  '|',
#  '|',
#  '|',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'W',
#  '<pad>',
#  'E',
#  '<pad>',
#  'R',
#  'E',
#  '|',
#  '|',
#  'A',
#  '|',
#  '|',
#  '|',
#  '<pad>',
#  'S',
#  'S',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'M',
#  'M',
#  '<pad>',
#  'A',
#  '<pad>',
#  '<pad>',
#  'L',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'L',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '|',
#  '|',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'B',
#  '<pad>',
#  'L',
#  'L',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'A',
#  '<pad>',
#  'C',
#  '<pad>',
#  '<pad>',
#  'K',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '|',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'P',
#  '<pad>',
#  'I',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'G',
#  '<pad>',
#  '<pad>',
#  '|',
#  '|',
#  'A',
#  'N',
#  '<pad>',
#  'D',
#  '|',
#  '|',
#  '|',
#  'A',
#  '|',
#  '|',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'L',
#  '<pad>',
#  '<pad>',
#  'U',
#  'U',
#  '<pad>',
#  '<pad>',
#  'S',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'T',
#  '<pad>',
#  '<pad>',
#  'Y',
#  '<pad>',
#  '|',
#  '|',
#  '<pad>',
#  'S',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'P',
#  '<pad>',
#  'E',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'C',
#  '<pad>',
#  'I',
#  'I',
#  '<pad>',
#  '<pad>',
#  'M',
#  '<pad>',
#  'E',
#  'N',
#  'N',
#  '<pad>',
#  '<pad>',
#  '|',
#  '|',
#  'O',
#  'F',
#  '|',
#  '|',
#  '|',
#  '<pad>',
#  '<pad>',
#  'B',
#  '<pad>',
#  'L',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'A',
#  '<pad>',
#  'C',
#  '<pad>',
#  '<pad>',
#  'K',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '|',
#  '|',
#  '<pad>',
#  '<pad>',
#  'R',
#  'R',
#  '<pad>',
#  'E',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'D',
#  'D',
#  '<pad>',
#  '|',
#  '|',
#  '|',
#  '<pad>',
#  'G',
#  'G',
#  '<pad>',
#  '<pad>',
#  'A',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'M',
#  'E',
#  'E',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  'C',
#  '<pad>',
#  'O',
#  'O',
#  '<pad>',
#  '<pad>',
#  'C',
#  '<pad>',
#  '<pad>',
#  'K',
#  '<pad>',
#  '<pad>',
#  '|',
#  '|',
#  '|',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>']

# %%
FRAME_SEC = 0.02  # 20 ms per token

events = []
current = None

for i, tok in enumerate(tokens):
    t = i * FRAME_SEC

    if tok == '<pad>':
        if current:
            current["end"] = t
            events.append(current)
            current = None
        continue

    if current and current["label"] == tok:
        # same sound continuing (elongation)
        continue

    if current:
        current["end"] = t
        events.append(current)

    current = {
        "label": tok,
        "start": t
    }

if current:
    current["end"] = t
    events.append(current)

events
# Out:
# [{'label': 'B', 'start': 0.54, 'end': 0.56},
#  {'label': 'E', 'start': 0.56, 'end': 0.58},
#  {'label': 'F', 'start': 0.66, 'end': 0.68},
#  {'label': 'O', 'start': 0.7000000000000001, 'end': 0.72},
#  {'label': 'R', 'start': 0.74, 'end': 0.76},
#  {'label': 'E', 'start': 0.76, 'end': 0.78},
#  {'label': '|', 'start': 0.8, 'end': 0.84},
#  {'label': 'H', 'start': 0.84, 'end': 0.88},
#  {'label': 'E', 'start': 0.88, 'end': 0.9},
#  {'label': '|', 'start': 0.92, 'end': 0.96},
#  {'label': 'H', 'start': 0.98, 'end': 1.0},
#  {'label': 'A', 'start': 1.02, 'end': 1.04},
#  {'label': 'D', 'start': 1.06, 'end': 1.08},
#  {'label': '|', 'start': 1.1, 'end': 1.1400000000000001},
#  {'label': 'T', 'start': 1.18, 'end': 1.22},
#  {'label': 'I', 'start': 1.24, 'end': 1.26},
#  {'label': 'M', 'start': 1.28, 'end': 1.32},
#  {'label': 'E', 'start': 1.32, 'end': 1.34},
#  {'label': '|', 'start': 1.36, 'end': 1.4000000000000001},
#  {'label': 'T', 'start': 1.4000000000000001, 'end': 1.42},
#  {'label': 'O', 'start': 1.42, 'end': 1.46},
#  {'label': '|', 'start': 1.46, 'end': 1.5},
#  {'label': 'A', 'start': 1.58, 'end': 1.6},
#  {'label': 'N', 'start': 1.6400000000000001, 'end': 1.68},
#  {'label': 'S', 'start': 1.74, 'end': 1.76},
#  {'label': 'W', 'start': 1.78, 'end': 1.8},
#  {'label': 'E', 'start': 1.82, 'end': 1.86},
#  {'label': 'R', 'start': 1.86, 'end': 1.9000000000000001},
#  {'label': '|', 'start': 1.94, 'end': 2.02},
#  {'label': 'A', 'start': 2.36, 'end': 2.38},
#  {'label': '|', 'start': 2.4, 'end': 2.44},
#  {'label': 'M', 'start': 2.54, 'end': 2.56},
#  {'label': 'U', 'start': 2.58, 'end': 2.6},
#  {'label': 'C', 'start': 2.66, 'end': 2.68},
#  {'label': 'H', 'start': 2.68, 'end': 2.72},
#  {'label': '|', 'start': 2.7600000000000002, 'end': 2.82},
#  {'label': 'E', 'start': 2.88, 'end': 2.9},
#  {'label': 'N', 'start': 2.9, 'end': 2.94},
#  {'label': 'C', 'start': 3.06, 'end': 3.08},
#  {'label': 'U', 'start': 3.1, 'end': 3.14},
#  {'label': 'M', 'start': 3.14, 'end': 3.18},
#  {'label': 'B', 'start': 3.24, 'end': 3.2600000000000002},
#  {'label': 'E', 'start': 3.2600000000000002, 'end': 3.3000000000000003},
#  {'label': 'R', 'start': 3.3200000000000003, 'end': 3.34},
#  {'label': 'E', 'start': 3.36, 'end': 3.38},
#  {'label': 'D', 'start': 3.4, 'end': 3.42},
#  {'label': '|', 'start': 3.42, 'end': 3.46},
#  {'label': 'V', 'start': 3.5, 'end': 3.52},
#  {'label': 'E', 'start': 3.54, 'end': 3.56},
#  {'label': 'R', 'start': 3.68, 'end': 3.72},
#  {'label': 'A', 'start': 3.7600000000000002, 'end': 3.7800000000000002},
#  {'label': '|', 'start': 3.86, 'end': 3.92},
#  {'label': 'B', 'start': 3.98, 'end': 4.0200000000000005},
#  {'label': 'U', 'start': 4.04, 'end': 4.0600000000000005},
#  {'label': 'R', 'start': 4.08, 'end': 4.12},
#  {'label': 'S', 'start': 4.18, 'end': 4.2},
#  {'label': 'T', 'start': 4.24, 'end': 4.26},
#  {'label': '|', 'start': 4.28, 'end': 4.32},
#  {'label': 'I', 'start': 4.32, 'end': 4.34},
#  {'label': 'N', 'start': 4.34, 'end': 4.38},
#  {'label': 'T', 'start': 4.42, 'end': 4.44},
#  {'label': 'O', 'start': 4.44, 'end': 4.46},
#  {'label': '|', 'start': 4.48, 'end': 4.5200000000000005},
#  {'label': 'T', 'start': 4.5200000000000005, 'end': 4.54},
#  {'label': 'H', 'start': 4.54, 'end': 4.5600000000000005},
#  {'label': 'E', 'start': 4.5600000000000005, 'end': 4.58},
#  {'label': '|', 'start': 4.58, 'end': 4.62},
#  {'label': 'R', 'start': 4.64, 'end': 4.66},
#  {'label': 'O', 'start': 4.66, 'end': 4.68},
#  {'label': 'O', 'start': 4.74, 'end': 4.76},
#  {'label': 'M', 'start': 4.78, 'end': 4.8},
#  {'label': '|', 'start': 4.82, 'end': 4.84},
#  {'label': 'W', 'start': 4.86, 'end': 4.88},
#  {'label': 'I', 'start': 4.88, 'end': 4.9},
#  {'label': 'T', 'start': 4.9, 'end': 4.92},
#  {'label': 'H', 'start': 4.92, 'end': 4.94},
#  {'label': '|', 'start': 4.94, 'end': 4.98},
#  {'label': 'T', 'start': 4.98, 'end': 5.0},
#  {'label': 'H', 'start': 5.0, 'end': 5.0200000000000005},
#  {'label': 'E', 'start': 5.0200000000000005, 'end': 5.04},
#  {'label': '|', 'start': 5.04, 'end': 5.0600000000000005},
#  {'label': 'Q', 'start': 5.08, 'end': 5.1000000000000005},
#  {'label': 'U', 'start': 5.1000000000000005, 'end': 5.14},
#  {'label': 'E', 'start': 5.14, 'end': 5.16},
#  {'label': 'S', 'start': 5.2, 'end': 5.22},
#  {'label': 'T', 'start': 5.26, 'end': 5.28},
#  {'label': 'I', 'start': 5.28, 'end': 5.32},
#  {'label': 'O', 'start': 5.32, 'end': 5.34},
#  {'label': 'N', 'start': 5.34, 'end': 5.38},
#  {'label': '|', 'start': 5.4, 'end': 5.48},
#  {'label': 'I', 'start': 5.9, 'end': 5.92},
#  {'label': '|', 'start': 5.94, 'end': 5.98},
#  {'label': 'S', 'start': 6.0200000000000005, 'end': 6.04},
#  {'label': 'A', 'start': 6.08, 'end': 6.1000000000000005},
#  {'label': 'Y', 'start': 6.12, 'end': 6.140000000000001},
#  {'label': '|', 'start': 6.18, 'end': 6.28},
#  {'label': 'C', 'start': 6.640000000000001, 'end': 6.66},
#  {'label': 'A', 'start': 6.66, 'end': 6.68},
#  {'label': 'N', 'start': 6.7, 'end': 6.72},
#  {'label': '|', 'start': 6.76, 'end': 6.8},
#  {'label': 'I', 'start': 6.8, 'end': 6.82},
#  {'label': '|', 'start': 6.82, 'end': 6.9},
#  {'label': 'L', 'start': 6.92, 'end': 6.94},
#  {'label': 'E', 'start': 6.94, 'end': 6.96},
#  {'label': 'A', 'start': 6.98, 'end': 7.0},
#  {'label': 'V', 'start': 7.0200000000000005, 'end': 7.04},
#  {'label': 'E', 'start': 7.04, 'end': 7.08},
#  {'label': '|', 'start': 7.08, 'end': 7.12},
#  {'label': 'T', 'start': 7.12, 'end': 7.140000000000001},
#  {'label': 'H', 'start': 7.140000000000001, 'end': 7.16},
#  {'label': 'E', 'start': 7.16, 'end': 7.18},
#  {'label': 'S', 'start': 7.24, 'end': 7.26},
#  {'label': 'E', 'start': 7.26, 'end': 7.28},
#  {'label': '|', 'start': 7.28, 'end': 7.32},
#  {'label': 'H', 'start': 7.34, 'end': 7.36},
#  {'label': 'E', 'start': 7.36, 'end': 7.4},
#  {'label': 'R', 'start': 7.44, 'end': 7.46},
#  {'label': 'E', 'start': 7.46, 'end': 7.5},
#  {'label': '|', 'start': 7.5200000000000005, 'end': 7.62},
#  {'label': 'T', 'start': 8.68, 'end': 8.700000000000001},
#  {'label': 'H', 'start': 8.700000000000001, 'end': 8.74},
#  {'label': 'E', 'start': 8.74, 'end': 8.76},
#  {'label': 'S', 'start': 9.0, 'end': 9.02},
#  {'label': 'E', 'start': 9.02, 'end': 9.06},
#  {'label': '|', 'start': 9.120000000000001, 'end': 9.200000000000001},
#  {'label': 'W', 'start': 9.44, 'end': 9.46},
#  {'label': 'E', 'start': 9.48, 'end': 9.5},
#  {'label': 'R', 'start': 9.52, 'end': 9.540000000000001},
#  {'label': 'E', 'start': 9.540000000000001, 'end': 9.56},
#  {'label': '|', 'start': 9.56, 'end': 9.6},
#  {'label': 'A', 'start': 9.6, 'end': 9.620000000000001},
#  {'label': '|', 'start': 9.620000000000001, 'end': 9.68},
#  {'label': 'S', 'start': 9.700000000000001, 'end': 9.74},
#  {'label': 'M', 'start': 9.82, 'end': 9.86},
#  {'label': 'A', 'start': 9.88, 'end': 9.9},
#  {'label': 'L', 'start': 9.94, 'end': 9.96},
#  {'label': 'L', 'start': 10.02, 'end': 10.040000000000001},
#  {'label': '|', 'start': 10.120000000000001, 'end': 10.16},
#  {'label': 'B', 'start': 10.22, 'end': 10.24},
#  {'label': 'L', 'start': 10.26, 'end': 10.3},
#  {'label': 'A', 'start': 10.36, 'end': 10.38},
#  {'label': 'C', 'start': 10.4, 'end': 10.42},
#  {'label': 'K', 'start': 10.46, 'end': 10.48},
#  {'label': '|', 'start': 10.540000000000001, 'end': 10.56},
#  {'label': 'P', 'start': 10.68, 'end': 10.700000000000001},
#  {'label': 'I', 'start': 10.72, 'end': 10.74},
#  {'label': 'G', 'start': 10.9, 'end': 10.92},
#  {'label': '|', 'start': 10.96, 'end': 11.0},
#  {'label': 'A', 'start': 11.0, 'end': 11.02},
#  {'label': 'N', 'start': 11.02, 'end': 11.040000000000001},
#  {'label': 'D', 'start': 11.06, 'end': 11.08},
#  {'label': '|', 'start': 11.08, 'end': 11.14},
#  {'label': 'A', 'start': 11.14, 'end': 11.16},
#  {'label': '|', 'start': 11.16, 'end': 11.200000000000001},
#  {'label': 'L', 'start': 11.26, 'end': 11.28},
#  {'label': 'U', 'start': 11.32, 'end': 11.36},
#  {'label': 'S', 'start': 11.4, 'end': 11.42},
#  {'label': 'T', 'start': 11.52, 'end': 11.540000000000001},
#  {'label': 'Y', 'start': 11.58, 'end': 11.6},
#  {'label': '|', 'start': 11.620000000000001, 'end': 11.66},
#  {'label': 'S', 'start': 11.68, 'end': 11.700000000000001},
#  {'label': 'P', 'start': 11.76, 'end': 11.78},
#  {'label': 'E', 'start': 11.8, 'end': 11.82},
#  {'label': 'C', 'start': 11.9, 'end': 11.92},
#  {'label': 'I', 'start': 11.94, 'end': 11.98},
#  {'label': 'M', 'start': 12.02, 'end': 12.040000000000001},
#  {'label': 'E', 'start': 12.06, 'end': 12.08},
#  {'label': 'N', 'start': 12.08, 'end': 12.120000000000001},
#  {'label': '|', 'start': 12.16, 'end': 12.200000000000001},
#  {'label': 'O', 'start': 12.200000000000001, 'end': 12.22},
#  {'label': 'F', 'start': 12.22, 'end': 12.24},
#  {'label': '|', 'start': 12.24, 'end': 12.3},
#  {'label': 'B', 'start': 12.34, 'end': 12.36},
#  {'label': 'L', 'start': 12.38, 'end': 12.4},
#  {'label': 'A', 'start': 12.46, 'end': 12.48},
#  {'label': 'C', 'start': 12.5, 'end': 12.52},
#  {'label': 'K', 'start': 12.56, 'end': 12.58},
#  {'label': '|', 'start': 12.64, 'end': 12.68},
#  {'label': 'R', 'start': 12.72, 'end': 12.76},
#  {'label': 'E', 'start': 12.780000000000001, 'end': 12.8},
#  {'label': 'D', 'start': 12.92, 'end': 12.96},
#  {'label': '|', 'start': 12.98, 'end': 13.040000000000001},
#  {'label': 'G', 'start': 13.06, 'end': 13.1},
#  {'label': 'A', 'start': 13.14, 'end': 13.16},
#  {'label': 'M', 'start': 13.24, 'end': 13.26},
#  {'label': 'E', 'start': 13.26, 'end': 13.3},
#  {'label': 'C', 'start': 13.46, 'end': 13.48},
#  {'label': 'O', 'start': 13.5, 'end': 13.540000000000001},
#  {'label': 'C', 'start': 13.58, 'end': 13.6},
#  {'label': 'K', 'start': 13.64, 'end': 13.66},
#  {'label': '|', 'start': 13.700000000000001, 'end': 13.76}]

# %%
pauses = []

for i in range(1, len(events)):
    gap = events[i]["start"] - events[i-1]["end"]
    if gap >= 0.3:  # 300 ms
        pauses.append({
            "type": "pause",
            "start": events[i-1]["end"],
            "end": events[i]["start"],
            "duration": gap
        })

pauses
# Out:
# [{'type': 'pause',
#   'start': 2.02,
#   'end': 2.36,
#   'duration': 0.33999999999999986},
#  {'type': 'pause', 'start': 5.48, 'end': 5.9, 'duration': 0.41999999999999993},
#  {'type': 'pause',
#   'start': 6.28,
#   'end': 6.640000000000001,
#   'duration': 0.3600000000000003},
#  {'type': 'pause', 'start': 7.62, 'end': 8.68, 'duration': 1.0599999999999996}]

# %%
stutters = []

for i in range(1, len(events)):
    prev = events[i - 1]
    curr = events[i]

    if (
        curr["label"] == prev["label"]
        and curr["start"] - prev["end"] < 0.05
    ):
        stutters.append({
            "type": "stutter",
            "label": curr["label"],
            "start": prev["start"],
            "end": curr["end"]
        })


stutters
# Out:
# []

# %%
FILLER_PATTERNS = [
    # --- Single vowel fillers (require duration >= threshold) ---
    ["A"],   # ah
    ["E"],   # eh
    ["U"],   # uh
    ["O"],   # oh

    # --- Repeated vowel elongations ---
    ["A", "A"],
    ["E", "E"],
    ["U", "U"],
    ["O", "O"],

    # --- Canonical English fillers ---
    ["U", "H"],   # uh
    ["E", "R"],   # er
    ["A", "H"],   # ah
    ["M", "M"],   # mm

    # --- Nasal thinking sounds ---
    ["M"],
    ["N"],
    ["M", "M", "M"],
    ["N", "N"],

    # --- Mixed vowel + nasal (umm / amm / unn) ---
    ["A", "M"],
    ["U", "M"],
    ["E", "M"],
    ["A", "N"],
    ["U", "N"],

    # --- Breathy hesitation ---
    ["H"],
    ["H", "H"],
]


FRAME_SEC = 0.02  # 20 ms per token

fillers = []

i = 1  # start at 1 so we can look left
while i < len(tokens) - 2:  # stop early so we can look right
    pair = [tokens[i], tokens[i + 1]]

    if pair in FILLER_PATTERNS:
        left = tokens[i - 1]
        right = tokens[i + 2]

        # 🔒 CRITICAL RULE: must be surrounded by silence
        if left == "<pad>" and right == "<pad>":
            start = i * FRAME_SEC
            end = (i + 2) * FRAME_SEC
            duration = end - start

            if duration >= 0.12:  # minimum audible filler
                fillers.append({
                    "type": "filler",
                    "label": "".join(pair).lower(),
                    "start": start,
                    "end": end,
                    "duration": duration
                })
            i += 2
        else:
            # embedded in a real word → ignore
            i += 1
    else:
        i += 1

fillers
# Out:
# []
